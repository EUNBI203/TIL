# %% [markdown]
# # 모든코인 상승장? 하락장?
# > 최고가와 최저가의 차이를 변동폭으로 정의할 때 (시가 + 변동폭)이 최고가 보다 높을 경우 "상승장", 그렇지 않은 경우 "하락장" 문자열을 출력하라.
#
#
# |Key Name|Description|
# |------|---|
# |opeing_price|최근 24시간 내 시작 거래금액|
# |closing_price|최근 24시간 내 마지막 거래금액|
# |min_price|최근 24시간 내 최저 거래금액|
# |max_price|최근 24시간 내 최고 거래금액|

# %%
import requests
import pprint

url = "https://api.bithumb.com/public/ticker/all"
data = requests.get(url).json()['data']
pprint.pprint(data)
# Out:
# {'ABT': {'24H_fluctate': '6',
#          '24H_fluctate_rate': '2.06',
#          'average_price': '301.8255',
#          'buy_price': '297',
#          'closing_price': '297',
#          'max_price': '318',
#          'min_price': '284',
#          'opening_price': '291',
#          'sell_price': '300',
#          'units_traded': '1511527.68031994',
#          'volume_1day': '1511527.68031994',
#          'volume_7day': '10468151.176067873398941736'},
#  'ADA': {'24H_fluctate': '5.1',
#          '24H_fluctate_rate': '5.55',
#          'average_price': '96.3192',
#          'buy_price': '96.9',
#          'closing_price': '96.9',
#          'max_price': '103',
#          'min_price': '91.3',
#          'opening_price': '91.8',
#          'sell_price': '97.2',
#          'units_traded': '6302676.89382842',
#          'volume_1day': '6302676.89382842',
#          'volume_7day': '63742250.10691858'},
#  'AE': {'24H_fluctate': '10',
#         '24H_fluctate_rate': '1.94',
#         'average_price': '534.5473',
#         'buy_price': '524',
#         'closing_price': '524',
#         'max_price': '570',
#         'min_price': '510',
#         'opening_price': '514',
#         'sell_price': '525',
#         'units_traded': '422774.24165147',
#         'volume_1day': '422774.24165147',
#         'volume_7day': '2469548.699217204196713173'},
#  'AMO': {'24H_fluctate': '0.01',
#          '24H_fluctate_rate': '1.56',
#          'average_price': '0.6409',
#          'buy_price': '0.64',
#          'closing_price': '0.65',
#          'max_price': '0.66',
#          'min_price': '0.61',
#          'opening_price': '0.64',
#          'sell_price': '0.65',
#          'units_traded': '318125197.54657477',
#          'volume_1day': '318125197.54657477',
#          'volume_7day': '3299328667.967524469475093072'},
#  'ANKR': {'24H_fluctate': '0.3',
#           '24H_fluctate_rate': '2.85',
#           'average_price': '10.581',
#           'buy_price': '10.7',
#           'closing_price': '10.8',
#           'max_price': '11.1',
#           'min_price': '10.1',
#           'opening_price': '10.5',
#           'sell_price': '10.8',
#           'units_traded': '90655926.61122948',
#           'volume_1day': '90655926.61122948',
#           'volume_7day': '687416497.424225913155368309'},
#  'APIS': {'24H_fluctate': '0.03',
#           '24H_fluctate_rate': '1.78',
#           'average_price': '1.7369',
#           'buy_price': '1.71',
#           'closing_price': '1.71',
#           'max_price': '1.9',
#           'min_price': '1.66',
#           'opening_price': '1.68',
#           'sell_price': '1.72',
#           'units_traded': '64886120.20359579',
#           'volume_1day': '64886120.20359579',
#           'volume_7day': '297970174.496810022513315604'},
#  'ARN': {'24H_fluctate': '0',
#          '24H_fluctate_rate': '0.00',
#          'average_price': '546.0508',
#          'buy_price': '531',
#          'closing_price': '530',
#          'max_price': '586',
#          'min_price': '516',
#          'opening_price': '530',
#          'sell_price': '535',
#          'units_traded': '293710.15562498',
#          'volume_1day': '293710.15562498',
#          'volume_7day': '1697945.75873984'},
#  'AUTO': {'24H_fluctate': '0',
#           '24H_fluctate_rate': '0.00',
#           'average_price': '1.6693',
#           'buy_price': '1.66',
#           'closing_price': '1.68',
#           'max_price': '1.73',
#           'min_price': '1.62',
#           'opening_price': '1.68',
#           'sell_price': '1.68',
#           'units_traded': '25229057.58915438',
#           'volume_1day': '25229057.58915438',
#           'volume_7day': '314662083.738913603262875436'},
#  'BAT': {'24H_fluctate': '-3',
#          '24H_fluctate_rate': '-1.05',
#          'average_price': '290.6565',
#          'buy_price': '281',
#          'closing_price': '281',
#          'max_price': '305',
#          'min_price': '276',
#          'opening_price': '284',
#          'sell_price': '285',
#          'units_traded': '679994.94052239',
#          'volume_1day': '679994.94052239',
#          'volume_7day': '8801708.494117355292766026'},
#  'BCD': {'24H_fluctate': '292',
#          '24H_fluctate_rate': '15.16',
#          'average_price': '2182.8776',
#          'buy_price': '2178',
#          'closing_price': '2217',
#          'max_price': '2367',
#          'min_price': '1872',
#          'opening_price': '1925',
#          'sell_price': '2217',
#          'units_traded': '830616.6033138',
#          'volume_1day': '830616.6033138',
#          'volume_7day': '1594428.43469003'},
#  'BCH': {'24H_fluctate': '29700',
#          '24H_fluctate_rate': '8.65',
#          'average_price': '370063.7119',
#          'buy_price': '372600',
#          'closing_price': '373000',
#          'max_price': '393600',
#          'min_price': '338000',
#          'opening_price': '343300',
#          'sell_price': '373000',
#          'units_traded': '37586.19082982',
#          'volume_1day': '37586.19082982',
#          'volume_7day': '215620.37718119'},
#  'BHP': {'24H_fluctate': '10',
#          '24H_fluctate_rate': '0.57',
#          'average_price': '1765.8733',
#          'buy_price': '1728',
#          'closing_price': '1739',
#          'max_price': '1871',
#          'min_price': '1680',
#          'opening_price': '1729',
#          'sell_price': '1736',
#          'units_traded': '711882.74838545',
#          'volume_1day': '711882.74838545',
#          'volume_7day': '1452785.21837654'},
#  'BSV': {'24H_fluctate': '13800',
#          '24H_fluctate_rate': '9.62',
#          'average_price': '151665.7106',
#          'buy_price': '157400',
#          'closing_price': '157200',
#          'max_price': '163600',
#          'min_price': '139100',
#          'opening_price': '143400',
#          'sell_price': '157800',
#          'units_traded': '75317.82328912',
#          'volume_1day': '75317.82328912',
#          'volume_7day': '298058.7003991'},
#  'BTC': {'24H_fluctate': '607000',
#          '24H_fluctate_rate': '4.92',
#          'average_price': '12789138.4514',
#          'buy_price': '12922000',
#          'closing_price': '12930000',
#          'max_price': '13451000',
#          'min_price': '12110000',
#          'opening_price': '12323000',
#          'sell_price': '12930000',
#          'units_traded': '12485.61124552',
#          'volume_1day': '12485.61124552',
#          'volume_7day': '89827.69338601'},
#  'BTG': {'24H_fluctate': '570',
#          '24H_fluctate_rate': '1.98',
#          'average_price': '29579.9068',
#          'buy_price': '29360',
#          'closing_price': '29350',
#          'max_price': '30800',
#          'min_price': '27800',
#          'opening_price': '28780',
#          'sell_price': '29680',
#          'units_traded': '21796.57443421',
#          'volume_1day': '21796.57443421',
#          'volume_7day': '239247.91849098'},
#  'BTT': {'24H_fluctate': '0.03',
#          '24H_fluctate_rate': '2.22',
#          'average_price': '1.3634',
#          'buy_price': '1.37',
#          'closing_price': '1.38',
#          'max_price': '1.53',
#          'min_price': '1.21',
#          'opening_price': '1.35',
#          'sell_price': '1.38',
#          'units_traded': '363518016.54411421',
#          'volume_1day': '363518016.54411421',
#          'volume_7day': '1520683817.58455152'},
#  'BZNT': {'24H_fluctate': '0.3',
#           '24H_fluctate_rate': '1.32',
#           'average_price': '22.7959',
#           'buy_price': '22.7',
#           'closing_price': '22.9',
#           'max_price': '23.4',
#           'min_price': '22.2',
#           'opening_price': '22.6',
#           'sell_price': '22.9',
#           'units_traded': '4007344.95076518',
#           'volume_1day': '4007344.95076518',
#           'volume_7day': '88260924.985414121635697606'},
#  'CMT': {'24H_fluctate': '1.9',
#          '24H_fluctate_rate': '3.02',
#          'average_price': '63.891',
#          'buy_price': '64.7',
#          'closing_price': '64.8',
#          'max_price': '67.7',
#          'min_price': '60.6',
#          'opening_price': '62.9',
#          'sell_price': '64.8',
#          'units_traded': '11744616.93656907',
#          'volume_1day': '11744616.93656907',
#          'volume_7day': '311969852.270278817746082999'},
#  'CON': {'24H_fluctate': '-0.1',
#          '24H_fluctate_rate': '-0.71',
#          'average_price': '14.0546',
#          'buy_price': '13.8',
#          'closing_price': '13.8',
#          'max_price': '14.5',
#          'min_price': '13.6',
#          'opening_price': '13.9',
#          'sell_price': '13.9',
#          'units_traded': '146675331.35474233',
#          'volume_1day': '146675331.35474233',
#          'volume_7day': '1188935245.277821531174817435'},
#  'CTXC': {'24H_fluctate': '4',
#           '24H_fluctate_rate': '0.82',
#           'average_price': '498.3736',
#           'buy_price': '487',
#           'closing_price': '487',
#           'max_price': '514',
#           'min_price': '481',
#           'opening_price': '483',
#           'sell_price': '490',
#           'units_traded': '405606.13953165',
#           'volume_1day': '405606.13953165',
#           'volume_7day': '8780517.532156528074863446'},
#  'DAC': {'24H_fluctate': '-0.16',
#          '24H_fluctate_rate': '-2.76',
#          'average_price': '5.7942',
#          'buy_price': '5.62',
#          'closing_price': '5.62',
#          'max_price': '6.04',
#          'min_price': '5.53',
#          'opening_price': '5.78',
#          'sell_price': '5.65',
#          'units_traded': '24930162.15864134',
#          'volume_1day': '24930162.15864134',
#          'volume_7day': '809814485.407539498430617996'},
#  'DACC': {'24H_fluctate': '0',
#           '24H_fluctate_rate': '0.00',
#           'average_price': '0.1648',
#           'buy_price': '0.16',
#           'closing_price': '0.17',
#           'max_price': '0.17',
#           'min_price': '0.15',
#           'opening_price': '0.17',
#           'sell_price': '0.17',
#           'units_traded': '403964753.65345881',
#           'volume_1day': '403964753.65345881',
#           'volume_7day': '2761293406.98181084'},
#  'DASH': {'24H_fluctate': '8400',
#           '24H_fluctate_rate': '5.45',
#           'average_price': '160723.7359',
#           'buy_price': '162400',
#           'closing_price': '162500',
#           'max_price': '170000',
#           'min_price': '149100',
#           'opening_price': '154100',
#           'sell_price': '162500',
#           'units_traded': '1382104.74796835',
#           'volume_1day': '1382104.74796835',
#           'volume_7day': '11465148.24679234'},
#  'ELF': {'24H_fluctate': '8',
#          '24H_fluctate_rate': '5.16',
#          'average_price': '161.6597',
#          'buy_price': '163',
#          'closing_price': '163',
#          'max_price': '170',
#          'min_price': '154',
#          'opening_price': '155',
#          'sell_price': '165',
#          'units_traded': '1056429.37332632',
#          'volume_1day': '1056429.37332632',
#          'volume_7day': '10393453.472207427790253715'},
#  'ENJ': {'24H_fluctate': '2',
#          '24H_fluctate_rate': '1.68',
#          'average_price': '120.2323',
#          'buy_price': '120',
#          'closing_price': '121',
#          'max_price': '126',
#          'min_price': '115',
#          'opening_price': '119',
#          'sell_price': '121',
#          'units_traded': '14999193.40774148',
#          'volume_1day': '14999193.40774148',
#          'volume_7day': '69396206.178152741951775443'},
#  'EOS': {'24H_fluctate': '-15',
#          '24H_fluctate_rate': '-0.29',
#          'average_price': '5186.1083',
#          'buy_price': '5115',
#          'closing_price': '5120',
#          'max_price': '5345',
#          'min_price': '4973',
#          'opening_price': '5135',
#          'sell_price': '5120',
#          'units_traded': '2157792.43928561',
#          'volume_1day': '2157792.43928561',
#          'volume_7day': '17635336.02033321'},
#  'ETC': {'24H_fluctate': '305',
#          '24H_fluctate_rate': '4.61',
#          'average_price': '6785.103',
#          'buy_price': '6915',
#          'closing_price': '6915',
#          'max_price': '7105',
#          'min_price': '6430',
#          'opening_price': '6610',
#          'sell_price': '6935',
#          'units_traded': '109739.28270036',
#          'volume_1day': '109739.28270036',
#          'volume_7day': '804640.209700136696968718'},
#  'ETH': {'24H_fluctate': '7100',
#          '24H_fluctate_rate': '2.65',
#          'average_price': '275773.79',
#          'buy_price': '274900',
#          'closing_price': '274900',
#          'max_price': '284900',
#          'min_price': '263800',
#          'opening_price': '267800',
#          'sell_price': '275000',
#          'units_traded': '108612.79489884',
#          'volume_1day': '108612.79489884',
#          'volume_7day': '611534.059838430177995066'},
#  'ETHOS': {'24H_fluctate': '9',
#            '24H_fluctate_rate': '6.12',
#            'average_price': '152.5858',
#            'buy_price': '155',
#            'closing_price': '156',
#            'max_price': '160',
#            'min_price': '144',
#            'opening_price': '147',
#            'sell_price': '156',
#            'units_traded': '2800629.26148568',
#            'volume_1day': '2800629.26148568',
#            'volume_7day': '45327947.40303607'},
#  'ETZ': {'24H_fluctate': '9',
#          '24H_fluctate_rate': '3.09',
#          'average_price': '303.0955',
#          'buy_price': '296',
#          'closing_price': '300',
#          'max_price': '318',
#          'min_price': '286',
#          'opening_price': '291',
#          'sell_price': '299',
#          'units_traded': '1257640.8886824',
#          'volume_1day': '1257640.8886824',
#          'volume_7day': '18474248.646923402404599144'},
#  'GNT': {'24H_fluctate': '2.3',
#          '24H_fluctate_rate': '3.03',
#          'average_price': '76.4221',
#          'buy_price': '76.5',
#          'closing_price': '78.1',
#          'max_price': '80',
#          'min_price': '73.3',
#          'opening_price': '75.8',
#          'sell_price': '78.1',
#          'units_traded': '400515.84122826',
#          'volume_1day': '400515.84122826',
#          'volume_7day': '5921813.652560664217182283'},
#  'GTO': {'24H_fluctate': '0.7',
#          '24H_fluctate_rate': '2.61',
#          'average_price': '27.7211',
#          'buy_price': '27.5',
#          'closing_price': '27.5',
#          'max_price': '29.5',
#          'min_price': '26.3',
#          'opening_price': '26.8',
#          'sell_price': '28.1',
#          'units_traded': '3001464.52787256',
#          'volume_1day': '3001464.52787256',
#          'volume_7day': '27950038.44623324'},
#  'GXC': {'24H_fluctate': '105',
#          '24H_fluctate_rate': '5.74',
#          'average_price': '1926.527',
#          'buy_price': '1901',
#          'closing_price': '1934',
#          'max_price': '2055',
#          'min_price': '1783',
#          'opening_price': '1829',
#          'sell_price': '1924',
#          'units_traded': '137015.57853304',
#          'volume_1day': '137015.57853304',
#          'volume_7day': '1681304.72546153'},
#  'HC': {'24H_fluctate': '113',
#         '24H_fluctate_rate': '2.87',
#         'average_price': '4184.6973',
#         'buy_price': '4016',
#         'closing_price': '4042',
#         'max_price': '4500',
#         'min_price': '3835',
#         'opening_price': '3929',
#         'sell_price': '4043',
#         'units_traded': '314734.55655185',
#         'volume_1day': '314734.55655185',
#         'volume_7day': '4504663.98526794'},
#  'HDAC': {'24H_fluctate': '0.4',
#           '24H_fluctate_rate': '1.32',
#           'average_price': '30.5964',
#           'buy_price': '30.3',
#           'closing_price': '30.7',
#           'max_price': '32.5',
#           'min_price': '28.8',
#           'opening_price': '30.3',
#           'sell_price': '30.7',
#           'units_traded': '2899900.59436981',
#           'volume_1day': '2899900.59436981',
#           'volume_7day': '34342165.88624786'},
#  'HYC': {'24H_fluctate': '0',
#          '24H_fluctate_rate': '0.00',
#          'average_price': '10.0071',
#          'buy_price': '9.89',
#          'closing_price': '9.99',
#          'max_price': '10.4',
#          'min_price': '9.73',
#          'opening_price': '9.99',
#          'sell_price': '9.99',
#          'units_traded': '60801456.16378012',
#          'volume_1day': '60801456.16378012',
#          'volume_7day': '1401354840.510557185'},
#  'ICX': {'24H_fluctate': '13',
#          '24H_fluctate_rate': '3.89',
#          'average_price': '343.4592',
#          'buy_price': '341',
#          'closing_price': '347',
#          'max_price': '357',
#          'min_price': '332',
#          'opening_price': '334',
#          'sell_price': '347',
#          'units_traded': '368569.53369322',
#          'volume_1day': '368569.53369322',
#          'volume_7day': '3713625.973063596870970941'},
#  'INS': {'24H_fluctate': '11',
#          '24H_fluctate_rate': '2.49',
#          'average_price': '456.2573',
#          'buy_price': '452',
#          'closing_price': '452',
#          'max_price': '488',
#          'min_price': '426',
#          'opening_price': '441',
#          'sell_price': '461',
#          'units_traded': '336861.12583019',
#          'volume_1day': '336861.12583019',
#          'volume_7day': '8533084.2453034909'},
#  'IOST': {'24H_fluctate': '0.3',
#           '24H_fluctate_rate': '2.54',
#           'average_price': '11.9076',
#           'buy_price': '12',
#           'closing_price': '12.1',
#           'max_price': '12.7',
#           'min_price': '11',
#           'opening_price': '11.8',
#           'sell_price': '12.2',
#           'units_traded': '3311892.9510255',
#           'volume_1day': '3311892.9510255',
#           'volume_7day': '39942797.99805144034281569'},
#  'ITC': {'24H_fluctate': '6',
#          '24H_fluctate_rate': '1.74',
#          'average_price': '355.8389',
#          'buy_price': '351',
#          'closing_price': '350',
#          'max_price': '375',
#          'min_price': '323',
#          'opening_price': '344',
#          'sell_price': '354',
#          'units_traded': '1525916.18628889',
#          'volume_1day': '1525916.18628889',
#          'volume_7day': '22375745.351699064799352276'},
#  'KNC': {'24H_fluctate': '12',
#          '24H_fluctate_rate': '5.58',
#          'average_price': '225.4874',
#          'buy_price': '225',
#          'closing_price': '227',
#          'max_price': '247',
#          'min_price': '213',
#          'opening_price': '215',
#          'sell_price': '228',
#          'units_traded': '529918.38565415',
#          'volume_1day': '529918.38565415',
#          'volume_7day': '5429761.28959698425300172'},
#  'LBA': {'24H_fluctate': '-0.4',
#          '24H_fluctate_rate': '-1.30',
#          'average_price': '31.1545',
#          'buy_price': '30.2',
#          'closing_price': '30.2',
#          'max_price': '32.3',
#          'min_price': '29.9',
#          'opening_price': '30.6',
#          'sell_price': '30.4',
#          'units_traded': '9228583.53839058',
#          'volume_1day': '9228583.53839058',
#          'volume_7day': '96855852.04443059765145354'},
#  'LINK': {'24H_fluctate': '145',
#           '24H_fluctate_rate': '3.20',
#           'average_price': '4679.8961',
#           'buy_price': '4640',
#           'closing_price': '4667',
#           'max_price': '4940',
#           'min_price': '4434',
#           'opening_price': '4522',
#           'sell_price': '4664',
#           'units_traded': '357185.75836085',
#           'volume_1day': '357185.75836085',
#           'volume_7day': '5098311.119693949339358063'},
#  'LOOM': {'24H_fluctate': '0.89',
#           '24H_fluctate_rate': '1.02',
#           'average_price': '87.3406',
#           'buy_price': '88.2',
#           'closing_price': '88.3',
#           'max_price': '91.5',
#           'min_price': '81.9',
#           'opening_price': '87.4',
#           'sell_price': '88.3',
#           'units_traded': '488101.28578112',
#           'volume_1day': '488101.28578112',
#           'volume_7day': '4378189.39622006979771485'},
#  'LRC': {'24H_fluctate': '-1.6',
#          '24H_fluctate_rate': '-2.10',
#          'average_price': '73.2515',
#          'buy_price': '72',
#          'closing_price': '74.4',
#          'max_price': '80.8',
#          'min_price': '70.1',
#          'opening_price': '76',
#          'sell_price': '73.7',
#          'units_traded': '547654.79648488',
#          'volume_1day': '547654.79648488',
#          'volume_7day': '5587940.271129428809595789'},
#  'LTC': {'24H_fluctate': '700',
#          '24H_fluctate_rate': '0.65',
#          'average_price': '108610.6283',
#          'buy_price': '107400',
#          'closing_price': '107300',
#          'max_price': '112200',
#          'min_price': '103500',
#          'opening_price': '106600',
#          'sell_price': '107500',
#          'units_traded': '21832.84683896',
#          'volume_1day': '21832.84683896',
#          'volume_7day': '175929.569948'},
#  'MCO': {'24H_fluctate': '40',
#          '24H_fluctate_rate': '0.66',
#          'average_price': '6062.7545',
#          'buy_price': '6075',
#          'closing_price': '6065',
#          'max_price': '6300',
#          'min_price': '5790',
#          'opening_price': '6025',
#          'sell_price': '6220',
#          'units_traded': '43184.11784906',
#          'volume_1day': '43184.11784906',
#          'volume_7day': '256741.28096217'},
#  'MITH': {'24H_fluctate': '1.2',
#           '24H_fluctate_rate': '2.59',
#           'average_price': '46.9317',
#           'buy_price': '45.9',
#           'closing_price': '47.4',
#           'max_price': '49.4',
#           'min_price': '45',
#           'opening_price': '46.2',
#           'sell_price': '47.4',
#           'units_traded': '3453402.64120772',
#           'volume_1day': '3453402.64120772',
#           'volume_7day': '15791679.23542620334584781'},
#  'MIX': {'24H_fluctate': '-1.3',
#          '24H_fluctate_rate': '-1.91',
#          'average_price': '67.1389',
#          'buy_price': '66.5',
#          'closing_price': '66.5',
#          'max_price': '69.6',
#          'min_price': '64.3',
#          'opening_price': '67.8',
#          'sell_price': '67.1',
#          'units_traded': '2775395.31756884',
#          'volume_1day': '2775395.31756884',
#          'volume_7day': '40290489.879543152128637568'},
#  'MTL': {'24H_fluctate': '180',
#          '24H_fluctate_rate': '9.31',
#          'average_price': '2073.3062',
#          'buy_price': '2089',
#          'closing_price': '2113',
#          'max_price': '2313',
#          'min_price': '1877',
#          'opening_price': '1933',
#          'sell_price': '2110',
#          'units_traded': '138544.07022698',
#          'volume_1day': '138544.07022698',
#          'volume_7day': '638221.22821716'},
#  'NPXS': {'24H_fluctate': '0.04',
#           '24H_fluctate_rate': '5.40',
#           'average_price': '0.7758',
#           'buy_price': '0.76',
#           'closing_price': '0.78',
#           'max_price': '0.82',
#           'min_price': '0.71',
#           'opening_price': '0.74',
#           'sell_price': '0.78',
#           'units_traded': '539963083.9302872',
#           'volume_1day': '539963083.9302872',
#           'volume_7day': '3240833505.179332208350640193'},
#  'OCN': {'24H_fluctate': '0.14',
#          '24H_fluctate_rate': '4.45',
#          'average_price': '3.2541',
#          'buy_price': '3.23',
#          'closing_price': '3.28',
#          'max_price': '3.46',
#          'min_price': '3.09',
#          'opening_price': '3.14',
#          'sell_price': '3.27',
#          'units_traded': '13014816.28637508',
#          'volume_1day': '13014816.28637508',
#          'volume_7day': '148117279.857134292031302212'},
#  'OMG': {'24H_fluctate': '-1',
#          '24H_fluctate_rate': '-0.05',
#          'average_price': '1880.765',
#          'buy_price': '1847',
#          'closing_price': '1848',
#          'max_price': '1960',
#          'min_price': '1774',
#          'opening_price': '1849',
#          'sell_price': '1861',
#          'units_traded': '537979.14161199',
#          'volume_1day': '537979.14161199',
#          'volume_7day': '3242509.27249715027697645'},
#  'ORBS': {'24H_fluctate': '0.1',
#           '24H_fluctate_rate': '0.34',
#           'average_price': '29.7167',
#           'buy_price': '29.4',
#           'closing_price': '29.5',
#           'max_price': '31',
#           'min_price': '28.6',
#           'opening_price': '29.4',
#           'sell_price': '29.5',
#           'units_traded': '17095709.90543787',
#           'volume_1day': '17095709.90543787',
#           'volume_7day': '129704857.540561028319004324'},
#  'PAY': {'24H_fluctate': '11',
#          '24H_fluctate_rate': '4.16',
#          'average_price': '271.4658',
#          'buy_price': '273',
#          'closing_price': '275',
#          'max_price': '290',
#          'min_price': '255',
#          'opening_price': '264',
#          'sell_price': '275',
#          'units_traded': '198108.77463513',
#          'volume_1day': '198108.77463513',
#          'volume_7day': '3325123.28181745684417128'},
#  'PIVX': {'24H_fluctate': '142',
#           '24H_fluctate_rate': '7.75',
#           'average_price': '1976.6604',
#           'buy_price': '1930',
#           'closing_price': '1974',
#           'max_price': '2228',
#           'min_price': '1692',
#           'opening_price': '1832',
#           'sell_price': '1972',
#           'units_traded': '78298.2633423',
#           'volume_1day': '78298.2633423',
#           'volume_7day': '656118.89609038'},
#  'PLY': {'24H_fluctate': '0.3',
#          '24H_fluctate_rate': '2.23',
#          'average_price': '13.7492',
#          'buy_price': '13.5',
#          'closing_price': '13.7',
#          'max_price': '14.4',
#          'min_price': '13.3',
#          'opening_price': '13.4',
#          'sell_price': '13.7',
#          'units_traded': '38040112.39709597',
#          'volume_1day': '38040112.39709597',
#          'volume_7day': '306850027.738506902'},
#  'POLY': {'24H_fluctate': '6.3',
#           '24H_fluctate_rate': '9.82',
#           'average_price': '75.5394',
#           'buy_price': '70.5',
#           'closing_price': '70.4',
#           'max_price': '88',
#           'min_price': '63',
#           'opening_price': '64.1',
#           'sell_price': '70.9',
#           'units_traded': '16310219.32997614',
#           'volume_1day': '16310219.32997614',
#           'volume_7day': '40541420.906601743308759825'},
#  'POWR': {'24H_fluctate': '1.7',
#           '24H_fluctate_rate': '1.73',
#           'average_price': '98.031',
#           'buy_price': '99',
#           'closing_price': '99.9',
#           'max_price': '103',
#           'min_price': '92',
#           'opening_price': '98.2',
#           'sell_price': '99.9',
#           'units_traded': '1021749.87567166',
#           'volume_1day': '1021749.87567166',
#           'volume_7day': '7707675.94334943'},
#  'PPT': {'24H_fluctate': '169',
#          '24H_fluctate_rate': '5.20',
#          'average_price': '3443.6346',
#          'buy_price': '3417',
#          'closing_price': '3418',
#          'max_price': '3646',
#          'min_price': '3203',
#          'opening_price': '3249',
#          'sell_price': '3418',
#          'units_traded': '119834.05501876',
#          'volume_1day': '119834.05501876',
#          'volume_7day': '1867511.93633827'},
#  'PST': {'24H_fluctate': '15',
#          '24H_fluctate_rate': '11.45',
#          'average_price': '145.3498',
#          'buy_price': '146',
#          'closing_price': '146',
#          'max_price': '157',
#          'min_price': '126',
#          'opening_price': '131',
#          'sell_price': '147',
#          'units_traded': '5234005.96602081',
#          'volume_1day': '5234005.96602081',
#          'volume_7day': '21452923.861864452474168705'},
#  'QTUM': {'24H_fluctate': '180',
#           '24H_fluctate_rate': '4.77',
#           'average_price': '3934.8569',
#           'buy_price': '3939',
#           'closing_price': '3950',
#           'max_price': '4152',
#           'min_price': '3691',
#           'opening_price': '3770',
#           'sell_price': '3950',
#           'units_traded': '459039.38108686',
#           'volume_1day': '459039.38108686',
#           'volume_7day': '3662554.16349371'},
#  'RDN': {'24H_fluctate': '81',
#          '24H_fluctate_rate': '8.81',
#          'average_price': '996.952',
#          'buy_price': '1002',
#          'closing_price': '1000',
#          'max_price': '1116',
#          'min_price': '876',
#          'opening_price': '919',
#          'sell_price': '1014',
#          'units_traded': '349957.17072998',
#          'volume_1day': '349957.17072998',
#          'volume_7day': '1978324.584579092717018458'},
#  'REP': {'24H_fluctate': '1900',
#          '24H_fluctate_rate': '10.43',
#          'average_price': '20644.9643',
#          'buy_price': '19790',
#          'closing_price': '20100',
#          'max_price': '24700',
#          'min_price': '18030',
#          'opening_price': '18200',
#          'sell_price': '20030',
#          'units_traded': '60527.59872207',
#          'volume_1day': '60527.59872207',
#          'volume_7day': '185574.492933156059250833'},
#  'RNT': {'24H_fluctate': '1.5',
#          '24H_fluctate_rate': '3.64',
#          'average_price': '41.7878',
#          'buy_price': '42.3',
#          'closing_price': '42.7',
#          'max_price': '43.9',
#          'min_price': '40.5',
#          'opening_price': '41.2',
#          'sell_price': '42.5',
#          'units_traded': '2134764.94723142',
#          'volume_1day': '2134764.94723142',
#          'volume_7day': '29935310.809398959215133828'},
#  'ROM': {'24H_fluctate': '-0.01',
#          '24H_fluctate_rate': '-20.00',
#          'average_price': '0.0446',
#          'buy_price': '0.04',
#          'closing_price': '0.04',
#          'max_price': '0.05',
#          'min_price': '0.04',
#          'opening_price': '0.05',
#          'sell_price': '0.05',
#          'units_traded': '1204104576.64578',
#          'volume_1day': '1204104576.64578',
#          'volume_7day': '19441514037.508573333333333336'},
#  'SALT': {'24H_fluctate': '2',
#           '24H_fluctate_rate': '0.95',
#           'average_price': '212.2238',
#           'buy_price': '210',
#           'closing_price': '211',
#           'max_price': '228',
#           'min_price': '203',
#           'opening_price': '209',
#           'sell_price': '211',
#           'units_traded': '398660.35933',
#           'volume_1day': '398660.35933',
#           'volume_7day': '2725854.37735264'},
#  'SNT': {'24H_fluctate': '0.9',
#          '24H_fluctate_rate': '3.75',
#          'average_price': '24.8435',
#          'buy_price': '24.9',
#          'closing_price': '24.9',
#          'max_price': '26.1',
#          'min_price': '23.7',
#          'opening_price': '24',
#          'sell_price': '25.3',
#          'units_traded': '4852243.1935606',
#          'volume_1day': '4852243.1935606',
#          'volume_7day': '53508452.59666821656894206'},
#  'STEEM': {'24H_fluctate': '1',
#            '24H_fluctate_rate': '0.25',
#            'average_price': '396.3467',
#            'buy_price': '392',
#            'closing_price': '393',
#            'max_price': '412',
#            'min_price': '375',
#            'opening_price': '392',
#            'sell_price': '397',
#            'units_traded': '606947.6184111',
#            'volume_1day': '606947.6184111',
#            'volume_7day': '12063342.75707131'},
#  'STRAT': {'24H_fluctate': '100',
#            '24H_fluctate_rate': '7.29',
#            'average_price': '1482.4172',
#            'buy_price': '1470',
#            'closing_price': '1470',
#            'max_price': '1600',
#            'min_price': '1351',
#            'opening_price': '1370',
#            'sell_price': '1482',
#            'units_traded': '254880.41134282',
#            'volume_1day': '254880.41134282',
#            'volume_7day': '1699370.16258857'},
#  'THETA': {'24H_fluctate': '4',
#            '24H_fluctate_rate': '3.60',
#            'average_price': '114.7238',
#            'buy_price': '113',
#            'closing_price': '115',
#            'max_price': '122',
#            'min_price': '110',
#            'opening_price': '111',
#            'sell_price': '114',
#            'units_traded': '724816.30326316',
#            'volume_1day': '724816.30326316',
#            'volume_7day': '6007013.903496666985828777'},
#  'TMTG': {'24H_fluctate': '0.04',
#           '24H_fluctate_rate': '1.86',
#           'average_price': '2.1839',
#           'buy_price': '2.19',
#           'closing_price': '2.19',
#           'max_price': '2.27',
#           'min_price': '2.07',
#           'opening_price': '2.15',
#           'sell_price': '2.2',
#           'units_traded': '49094528.91174638',
#           'volume_1day': '49094528.91174638',
#           'volume_7day': '284665879.982542867958841878'},
#  'TRUE': {'24H_fluctate': '16',
#           '24H_fluctate_rate': '2.99',
#           'average_price': '554.8201',
#           'buy_price': '539',
#           'closing_price': '551',
#           'max_price': '598',
#           'min_price': '515',
#           'opening_price': '535',
#           'sell_price': '551',
#           'units_traded': '529439.19130368',
#           'volume_1day': '529439.19130368',
#           'volume_7day': '4489167.948444593020669752'},
#  'TRX': {'24H_fluctate': '0.5',
#          '24H_fluctate_rate': '1.74',
#          'average_price': '29.3878',
#          'buy_price': '29.1',
#          'closing_price': '29.1',
#          'max_price': '30.3',
#          'min_price': '28.4',
#          'opening_price': '28.6',
#          'sell_price': '29.2',
#          'units_traded': '71899629.87321206',
#          'volume_1day': '71899629.87321206',
#          'volume_7day': '570310863.01805638'},
#  'VALOR': {'24H_fluctate': '137',
#            '24H_fluctate_rate': '5.65',
#            'average_price': '2562.5535',
#            'buy_price': '2560',
#            'closing_price': '2560',
#            'max_price': '2696',
#            'min_price': '2409',
#            'opening_price': '2423',
#            'sell_price': '2575',
#            'units_traded': '103296.0087675',
#            'volume_1day': '103296.0087675',
#            'volume_7day': '1142065.651793602869914978'},
#  'VET': {'24H_fluctate': '0.32',
#          '24H_fluctate_rate': '4.41',
#          'average_price': '7.4399',
#          'buy_price': '7.41',
#          'closing_price': '7.57',
#          'max_price': '7.78',
#          'min_price': '7.19',
#          'opening_price': '7.25',
#          'sell_price': '7.57',
#          'units_traded': '14207238.84407113',
#          'volume_1day': '14207238.84407113',
#          'volume_7day': '137982995.624039665291439038'},
#  'WAVES': {'24H_fluctate': '580',
#            '24H_fluctate_rate': '27.67',
#            'average_price': '2738.9061',
#            'buy_price': '2614',
#            'closing_price': '2676',
#            'max_price': '3250',
#            'min_price': '2075',
#            'opening_price': '2096',
#            'sell_price': '2680',
#            'units_traded': '809104.21900782',
#            'volume_1day': '809104.21900782',
#            'volume_7day': '1417098.62569412'},
#  'WAX': {'24H_fluctate': '2.2',
#          '24H_fluctate_rate': '3.54',
#          'average_price': '64.4642',
#          'buy_price': '64.2',
#          'closing_price': '64.2',
#          'max_price': '70',
#          'min_price': '61.9',
#          'opening_price': '62',
#          'sell_price': '65.1',
#          'units_traded': '1884295.90333427',
#          'volume_1day': '1884295.90333427',
#          'volume_7day': '17532914.16338612'},
#  'WET': {'24H_fluctate': '0',
#          '24H_fluctate_rate': '0.00',
#          'average_price': '15.2719',
#          'buy_price': '15.2',
#          'closing_price': '15.3',
#          'max_price': '15.8',
#          'min_price': '14.8',
#          'opening_price': '15.3',
#          'sell_price': '15.3',
#          'units_traded': '11277757.98541207',
#          'volume_1day': '11277757.98541207',
#          'volume_7day': '129250316.908702978303497485'},
#  'WTC': {'24H_fluctate': '32',
#          '24H_fluctate_rate': '1.24',
#          'average_price': '2755.6471',
#          'buy_price': '2601',
#          'closing_price': '2603',
#          'max_price': '3105',
#          'min_price': '2551',
#          'opening_price': '2571',
#          'sell_price': '2624',
#          'units_traded': '233578.06709594',
#          'volume_1day': '233578.06709594',
#          'volume_7day': '5298580.479147762054603445'},
#  'XEM': {'24H_fluctate': '4.9',
#          '24H_fluctate_rate': '5.15',
#          'average_price': '98.6319',
#          'buy_price': '98.7',
#          'closing_price': '100',
#          'max_price': '104',
#          'min_price': '92.7',
#          'opening_price': '95.1',
#          'sell_price': '100',
#          'units_traded': '1084421.22377478',
#          'volume_1day': '1084421.22377478',
#          'volume_7day': '12233251.16232312'},
#  'XLM': {'24H_fluctate': '1',
#          '24H_fluctate_rate': '0.90',
#          'average_price': '112.3889',
#          'buy_price': '111',
#          'closing_price': '111',
#          'max_price': '117',
#          'min_price': '107',
#          'opening_price': '110',
#          'sell_price': '113',
#          'units_traded': '2752771.99789086',
#          'volume_1day': '2752771.99789086',
#          'volume_7day': '23293664.71595933'},
#  'XMR': {'24H_fluctate': '9400',
#          '24H_fluctate_rate': '10.15',
#          'average_price': '97060.1643',
#          'buy_price': '101400',
#          'closing_price': '102000',
#          'max_price': '107700',
#          'min_price': '92300',
#          'opening_price': '92600',
#          'sell_price': '102100',
#          'units_traded': '2837678.79909977',
#          'volume_1day': '2837678.79909977',
#          'volume_7day': '17505937.974747498411'},
#  'XRP': {'24H_fluctate': '2',
#          '24H_fluctate_rate': '0.53',
#          'average_price': '379.3005',
#          'buy_price': '376',
#          'closing_price': '377',
#          'max_price': '391',
#          'min_price': '369',
#          'opening_price': '375',
#          'sell_price': '377',
#          'units_traded': '82959024.97394874',
#          'volume_1day': '82959024.97394874',
#          'volume_7day': '648834364.17258251'},
#  'XVG': {'24H_fluctate': '0.5',
#          '24H_fluctate_rate': '3.44',
#          'average_price': '14.7172',
#          'buy_price': '14.7',
#          'closing_price': '15',
#          'max_price': '15.7',
#          'min_price': '13.9',
#          'opening_price': '14.5',
#          'sell_price': '15',
#          'units_traded': '1621865.92072629',
#          'volume_1day': '1621865.92072629',
#          'volume_7day': '21617915.61778351'},
#  'ZEC': {'24H_fluctate': '5000',
#          '24H_fluctate_rate': '4.85',
#          'average_price': '105752.7102',
#          'buy_price': '108200',
#          'closing_price': '108000',
#          'max_price': '118300',
#          'min_price': '96200',
#          'opening_price': '103000',
#          'sell_price': '118300',
#          'units_traded': '2382.99013041',
#          'volume_1day': '2382.99013041',
#          'volume_7day': '15602.49947157'},
#  'ZIL': {'24H_fluctate': '0.6',
#          '24H_fluctate_rate': '3.63',
#          'average_price': '16.9851',
#          'buy_price': '16.9',
#          'closing_price': '17.1',
#          'max_price': '17.5',
#          'min_price': '16.3',
#          'opening_price': '16.5',
#          'sell_price': '17',
#          'units_traded': '7107546.93277006',
#          'volume_1day': '7107546.93277006',
#          'volume_7day': '61783218.189598164443'},
#  'ZRX': {'24H_fluctate': '44',
#          '24H_fluctate_rate': '16.85',
#          'average_price': '305.2959',
#          'buy_price': '304',
#          'closing_price': '305',
#          'max_price': '328',
#          'min_price': '260',
#          'opening_price': '261',
#          'sell_price': '306',
#          'units_traded': '1619047.50525247',
#          'volume_1day': '1619047.50525247',
#          'volume_7day': '4613685.577089674745890539'},
#  'date': '1563256136628'}

# %%
for key, value in data.items():
    if key != 'date':
        if float(value['opening_price']) + float(value['max_price']) - float(value['min_price']) > float(value['max_price']):
            print(f'{key} : 상승장')
        else:
            print(f'{key} : 하락장')
# Out:
# BTC : 상승장
# ETH : 상승장
# DASH : 상승장
# LTC : 상승장
# ETC : 상승장
# XRP : 상승장
# BCH : 상승장
# XMR : 상승장
# ZEC : 상승장
# QTUM : 상승장
# BTG : 상승장
# EOS : 상승장
# ICX : 상승장
# VET : 상승장
# TRX : 상승장
# ELF : 상승장
# MITH : 상승장
# MCO : 상승장
# OMG : 상승장
# KNC : 상승장
# GNT : 상승장
# ZIL : 상승장
# ETHOS : 상승장
# PAY : 상승장
# WAX : 상승장
# POWR : 상승장
# LRC : 상승장
# GTO : 상승장
# STEEM : 상승장
# STRAT : 상승장
# ZRX : 상승장
# REP : 상승장
# AE : 상승장
# XEM : 상승장
# SNT : 상승장
# ADA : 상승장
# PPT : 상승장
# CTXC : 상승장
# CMT : 상승장
# THETA : 상승장
# WTC : 상승장
# ITC : 상승장
# TRUE : 상승장
# ABT : 상승장
# RNT : 상승장
# PLY : 상승장
# WAVES : 상승장
# LINK : 상승장
# ENJ : 상승장
# PST : 상승장
# SALT : 상승장
# RDN : 상승장
# LOOM : 상승장
# PIVX : 상승장
# INS : 상승장
# BCD : 상승장
# BZNT : 상승장
# XLM : 상승장
# OCN : 상승장
# BSV : 상승장
# TMTG : 상승장
# BAT : 상승장
# WET : 상승장
# XVG : 상승장
# IOST : 상승장
# POLY : 상승장
# HC : 상승장
# ROM : 상승장
# AMO : 상승장
# ETZ : 상승장
# ARN : 상승장
# APIS : 상승장
# MTL : 상승장
# DACC : 상승장
# DAC : 상승장
# BHP : 상승장
# BTT : 상승장
# HDAC : 상승장
# NPXS : 상승장
# AUTO : 상승장
# GXC : 상승장
# ORBS : 상승장
# VALOR : 상승장
# CON : 상승장
# ANKR : 상승장
# MIX : 상승장
# HYC : 상승장
# LBA : 상승장

# %%
for coin, coin_data in data.items():
    if type(coin_data) == type(dict()):
        if float(coin_data['opening_price']) - float(coin_data['min_price']) > 0:
            print(f'{coin} : 상승장')
        else:
            print(f'{coin} : 하락장')
# Out:
# BTC : 상승장
# ETH : 상승장
# DASH : 상승장
# LTC : 상승장
# ETC : 상승장
# XRP : 상승장
# BCH : 상승장
# XMR : 상승장
# ZEC : 상승장
# QTUM : 상승장
# BTG : 상승장
# EOS : 상승장
# ICX : 상승장
# VET : 상승장
# TRX : 상승장
# ELF : 상승장
# MITH : 상승장
# MCO : 상승장
# OMG : 상승장
# KNC : 상승장
# GNT : 상승장
# ZIL : 상승장
# ETHOS : 상승장
# PAY : 상승장
# WAX : 상승장
# POWR : 상승장
# LRC : 상승장
# GTO : 상승장
# STEEM : 상승장
# STRAT : 상승장
# ZRX : 상승장
# REP : 상승장
# AE : 상승장
# XEM : 상승장
# SNT : 상승장
# ADA : 상승장
# PPT : 상승장
# CTXC : 상승장
# CMT : 상승장
# THETA : 상승장
# WTC : 상승장
# ITC : 상승장
# TRUE : 상승장
# ABT : 상승장
# RNT : 상승장
# PLY : 상승장
# WAVES : 상승장
# LINK : 상승장
# ENJ : 상승장
# PST : 상승장
# SALT : 상승장
# RDN : 상승장
# LOOM : 상승장
# PIVX : 상승장
# INS : 상승장
# BCD : 상승장
# BZNT : 상승장
# XLM : 상승장
# OCN : 상승장
# BSV : 상승장
# TMTG : 상승장
# BAT : 상승장
# WET : 상승장
# XVG : 상승장
# IOST : 상승장
# POLY : 상승장
# HC : 상승장
# ROM : 상승장
# AMO : 상승장
# ETZ : 상승장
# ARN : 상승장
# APIS : 상승장
# MTL : 상승장
# DACC : 상승장
# DAC : 상승장
# BHP : 상승장
# BTT : 상승장
# HDAC : 상승장
# NPXS : 상승장
# AUTO : 상승장
# GXC : 상승장
# ORBS : 상승장
# VALOR : 상승장
# CON : 상승장
# ANKR : 상승장
# MIX : 상승장
# HYC : 상승장
# LBA : 상승장

# %% [markdown]
# # 평균점수
# > 다음 딕셔너리에서 평균 점수를 출력하라

# %%
student = {'python':80, 'algorithm':78, 'django':95, 'flask':80}
s = 0
for score in student.values():
    s += score
print(f'평균점수 : {s/len(student.values())}')
#print(f'평균점수 : {sum(student.values())/len(student.values())}')
# Out:
# 평균점수 : 83.25
# 평균점수 : 83.25

# %% [markdown]
# # 혈액형
# > 학생들의 혈액형(A,B,O,AB)에 대한 데이터가 리스트에 들어있다. 각 혈액형이 몇명인지 딕셔너리를 만들어 출력하라

# %%
blood = ['A','A','B','O','A','B','A','AB','AB','O','A','O','AB','O']
a = 0
b = 0
ab = 0
o = 0
for i in blood:
    if i == 'A':
        a += 1
    elif i == 'B':
        b += 1
    elif i == 'AB':
        ab += 1
    elif i == 'O':
        o += 1
dic = {'A':a, 'B':b, 'AB':ab, 'O':o}
print(dic)
# Out:
# {'A': 5, 'B': 2, 'AB': 3, 'O': 4}

# %%
# 2번째 방법
blood_dict = {}
blood = ['A','A','B','O','A','B','A','AB','AB','O','A','O','AB','O']

# 하나씩 꺼내서 확인한다.
for blood_type in blood:
    # 지금 나온적이 없으면, 키와 value 1로 만든다.
    if blood_type not in blood_dict.keys():
        blood_dict[blood_type] = 1
    else:
        blood_dict[blood_type] += 1
print(blood_dict)
# Out:
# {'A': 5, 'B': 2, 'O': 4, 'AB': 3}

# %%
{blood_type: blood.count(blood_type) for blood_type in set(blood)}
# Out:
# {'AB': 3, 'O': 4, 'A': 5, 'B': 2}

# %%
blood.count('A')
# Out:
# 5

# %% [markdown]
# # UBD
# > movies는 영화제목이 key로 누적관객수가 value인 딕셔너리이다.
# >
# > 자전차왕 엄복동의 누적관객수는 172212명이고 172212명을 1UBD라고 할때 80UBD를 넘지 못하는 영화를 출력하라.

# %%
movies = {
    "7번방의선물":12811206,
    "괴물":13019740,
    "국제시장":14257115,
    "극한직업":16261018,
    "도둑들":12983330,
    "명량":17613682,
    "베테랑":13414009,
    "신과함께-죄와벌":14410754,
    "아바타":13624328,
    "어벤져스:엔드게임":13901423,
}

UBD = 172212

for movie in movies.keys():
    if movies[movie] < 80 * UBD:
        print(movie)
else:
    print(f'80UBD : {80*UBD}')
# Out:
# 7번방의선물
# 괴물
# 도둑들
# 베테랑
# 아바타
# 80UBD : 13776960
